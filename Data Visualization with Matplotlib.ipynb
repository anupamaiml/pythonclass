# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
x = np.linspace(0, 10, 20)

# %%
x
# Out:
# array([ 0.        ,  0.52631579,  1.05263158,  1.57894737,  2.10526316,
#         2.63157895,  3.15789474,  3.68421053,  4.21052632,  4.73684211,
#         5.26315789,  5.78947368,  6.31578947,  6.84210526,  7.36842105,
#         7.89473684,  8.42105263,  8.94736842,  9.47368421, 10.        ])

# %%
y = np.random.randint(0, 50, 20)

# %%
y
# Out:
# array([ 1, 13, 49, 38, 10, 23, 31, 33, 37, 15, 20, 19, 40,  4, 48, 19, 17,
#        47, 42, 29])

# %%
y = np.sort(y)

# %%
y
# Out:
# array([ 1,  4, 10, 13, 15, 17, 19, 19, 20, 23, 29, 31, 33, 37, 38, 40, 42,
#        47, 48, 49])

# %%
plt.plot(x,y, color = 'r', marker = 'o')
plt.xlabel('X axis')
plt.ylabel('Y axis')
plt.title('X vs Y')
plt.show()

# %%
iris = pd.read_csv("iris.csv")

# %%
iris
# Out:
#      sepal length in cm  sepal width in cm  petal length in cm  \
# 0                   5.1                3.5                 1.4
# 1                   4.9                3.0                 1.4
# 2                   4.7                3.2                 1.3
# 3                   4.6                3.1                 1.5
# 4                   5.0                3.6                 1.4
# ..                  ...                ...                 ...
# 145                 6.7                3.0                 5.2
# 146                 6.3                2.5                 5.0
# 147                 6.5                3.0                 5.2
# 148                 6.2                3.4                 5.4
# 149                 5.9                3.0                 5.1
#
#      petal width in cm         outputs
# 0                  0.2     Iris-setosa
# 1                  0.2     Iris-setosa
# 2                  0.2     Iris-setosa
# 3                  0.2     Iris-setosa
# ...

# %%
iris['outputs'].nunique()
# Out:
# 3

# %%
iris['outputs'].value_counts()
# Out:
# Iris-setosa        50
# Iris-virginica     50
# Iris-versicolor    50
# Name: outputs, dtype: int64

# %%
iris.plot(figsize=(12,8))

# %%
iris.plot.scatter(x = 'petal length in cm', y = 'sepal width in cm')

# %%
titanic = pd.read_csv("titanic - Copy.csv")

# %%
titanic
# Out:
#      Survived  Pclass                                               Name  \
# 0           0       3                             Mr. Owen Harris Braund
# 1           1       1  Mrs. John Bradley (Florence Briggs Thayer) Cum...
# 2           1       3                              Miss. Laina Heikkinen
# 3           1       1        Mrs. Jacques Heath (Lily May Peel) Futrelle
# 4           0       3                            Mr. William Henry Allen
# ..        ...     ...                                                ...
# 882         0       2                               Rev. Juozas Montvila
# 883         1       1                        Miss. Margaret Edith Graham
# 884         0       3                     Miss. Catherine Helen Johnston
# 885         1       1                               Mr. Karl Howell Behr
# 886         0       3                                 Mr. Patrick Dooley
#
#         Sex   Age  Siblings/Spouses Aboard  Parents/Children Aboard     Fare
# ...

# %%
titanic['Sex'].value_counts().sort_index().plot.bar()

# %%
titanic['Survived'].value_counts().sort_index().plot.bar()

# %%
titanic['Pclass'].value_counts().sort_index().plot.barh()

# %%
iris.plot(subplots = True, figsize=(15,9), layout = (2,2))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x0000020FE0A21848>,
# ...
#       dtype=object)

# %%
iris.plot(kind = 'box', figsize=(15,8))

# %%
iris.plot.hist(subplots = True, layout = (2,2), figsize=(12,8), bins = 20)
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x0000020FE257E708>,
# ...
#       dtype=object)

# %%
iris.plot(kind = 'kde', figsize=(18,6))
